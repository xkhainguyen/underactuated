# %% [markdown]
# ### Exercise 5.1 (Footstep Planning via Mixed-Integer Optimization)
# In this exercise we implement a simplified version of the footstep planning method proposed in [5]. You will find all the details this python notebook. Your goal is to code most of the components of the mixed-integer program at the core of the footstep planner:
#
# *Check my code*
#
# ### Exercise 5.2 (Understanding the zero moment point)
# Consider an abstracted legged robot. The foot and the leg are assumed to be massless. Suppose there is no actuator at the pin joint P
#
# a. Yes, the projection of the robot's center of mass belongs to the convex hull of contact points.
#
# b. $r_x = \frac{3L_2+L_1+2\ell \text{cos}(\theta)}{4}$
# I put my coordinate at H. Not so sure, please let me know if you have a different answer.
#
# c.
#
# i. Solve for $r_x = L_1 + L_2$
#
# ii. Consider the toe T as the rotating point. The heel H begin to lift when CoM project lies on the right of T. Solve for
#
# $\ell \text{cos}(\theta)+L_2 \geq {L_1+L_2}$
#
# d. I feel like they are the same.
#
# e. Just from my intution (please correct me if I'm wrong)
#
# i. Flatter foot. Lower CoM.
#
# ii. Longer foot. Larger convex hull.
#
# iii. The ankle should be close to the heel. Better forward stability.
#
# f. Just from my intution (please correct me if I'm wrong)
#
# i. Taller foot helps to move faster but flatter foot increases stability.
#
# ii. Greater $L_1$ means greater forward stability but need more force (to counter friction).
#
# iii. Greater $L_2$ (relative to $L_1$) helps stance stability but need more force (to counter friction).
#
# *I feel like if ones have really big feet, their static gait stability is great. But for running (dynamic gait), smaller feet make it faster and more energy-efficient.*

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4c082fe8-3f50-42d0-8689-4dfb2ea7b2b9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
